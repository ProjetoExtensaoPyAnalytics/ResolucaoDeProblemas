# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
doencas = pd.read_csv('obitos - completo.csv')

# %%
doencas
# Out:
#                                              Indicador   2006   2007   2008  \
# 0                                               Óbitos  304.0  339.0  318.0
# 1                                                Total  172.0  196.0  189.0
# 2                              Menos de 1 ano de idade    2.0    2.0    6.0
# 3                                  1 a 4 anos de idade    2.0    NaN    2.0
# 4                                           5 a 9 anos    1.0    NaN    1.0
# ..                                                 ...    ...    ...    ...
# 120         Causas externas de morbidade e mortalidade    NaN    NaN    NaN
# 121  Fatores que influenciam o estado de saúde e o ...    NaN    NaN    NaN
# 122  Fatores que influenciam o estado de saúde e o ...    NaN    NaN    NaN
# 123  Fatores que influenciam o estado de saúde e o ...    NaN    NaN    NaN
# 124  Fatores que influenciam o estado de saúde e o ...    NaN    NaN    NaN
#
# ...

# %%
doencas.fillna('', inplace=True)
# Out:
# C:\Users\Labmidia\AppData\Local\Temp\ipykernel_2248\3662891971.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   doencas.fillna('', inplace=True)

# %%
doencas.isnull().sum()
# Out:
# Indicador    0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# 2014         0
# 2015         0
# 2016         0
# 2017         0
# 2018         0
# 2019         0
# 2020         0
# 2021         0
# 2022         0
# Etiqueta     0
# dtype: int64

# %%
doencas
# Out:
#                                              Indicador   2006   2007   2008  \
# 0                                               Óbitos  304.0  339.0  318.0
# 1                                                Total  172.0  196.0  189.0
# 2                              Menos de 1 ano de idade    2.0    2.0    6.0
# 3                                  1 a 4 anos de idade    2.0           2.0
# 4                                           5 a 9 anos    1.0           1.0
# ..                                                 ...    ...    ...    ...
# 120         Causas externas de morbidade e mortalidade
# 121  Fatores que influenciam o estado de saúde e o ...
# 122  Fatores que influenciam o estado de saúde e o ...
# 123  Fatores que influenciam o estado de saúde e o ...
# 124  Fatores que influenciam o estado de saúde e o ...
#
#       2009   2010   2011  2012  2013   2014   2015  2016  2017  2018  2019  \
# 0    340.0  380.0  408.0   323   357  405.0  394.0   420   385   424   387
# ...

# %%
doencas['Indicador'].unique()
# Out:
# array(['Óbitos', 'Total', 'Menos de 1 ano de idade',
#        '1 a 4 anos de idade', '5 a 9 anos', '10 a 14 anos de idade',
#        '15 a 19 anos', '20 a 29 anos de idade', '30 a 39 anos de idade',
#        '40 a 49 anos de idade', '50 a 59 anos de idade',
#        '60 a 69 anos de idade', '70 a 79 anos de idade',
#        '80 anos ou mais de idade', 'Idade ignorada', 'Ignorado',
#        'Algumas doenças infecciosas e parasitárias',
#        'Neoplasmas (Tumores)',
#        'Doenças do sangue e dos órgãos hematopoéticos e alguns transtornos imunitários',
#        'Doenças endócrinas, nutricionais e metabólicas',
#        'Transtornos mentais e comportamentais',
#        'Doenças do sistema nervoso', 'Doenças do olho e anexos',
#        'Doenças do ouvido e da apófise mastóide',
#        'Doenças do aparelho circulatório',
#        'Doenças do aparelho respiratório',
#        'Doenças do aparelho digestivo',
#        'Doenças da pele e do tecido subcutâneo',
# ...

# %%
doencas['Etiqueta'].unique()
# Out:
# array(['Total', 'Total_Marculino_Grupo de Idade',
#        'Marculino_Grupo de Idade', 'Total_Feminino_Grupo de Idade',
#        'Feminino_Grupo de Idade', 'Menos de 1 ano de idade',
#        'Total_Grupo de Idade', 'Masculino', 'Femino', 'Ignorado',
#        'Feminino', 'Feminno', 'óbitos'], dtype=object)
